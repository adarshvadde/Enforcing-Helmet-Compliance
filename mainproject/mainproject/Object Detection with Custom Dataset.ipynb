# %%
#!pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu116

# %%
#!pip install --upgrade pip

# %%
#!git clone https://github.com/ultralytics/yolov5

# %%
#!cd yolov5 & pip install -r requirements.txt
# Out:
# ...
# DEPRECATION: Loading egg at c:\users\siva\appdata\local\programs\python\python311\lib\site-packages\apache_beam-2.54.0rc2-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\siva\appdata\local\programs\python\python311\lib\site-packages\avro_python3-1.10.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\siva\appdata\local\programs\python\python311\lib\site-packages\lvis-0.5.3-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...

# %%
#!pip install matplotlib

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
import os

# %%
#!pip install pandas

# %%
#!pip install pyyaml

# %%
#!pip install tqdm

# %%
#!pip install seaborn

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\Siva/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-2-8 Python-3.11.1 torch-2.2.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
img = "D:/projects/projectws/shanmukl/number plate detection/bikes/2.png"

# %%
result = model(img)
result.print()
# Out:
# image 1/1: 434x308 1 person
# Speed: 76.1ms pre-process, 470.5ms inference, 15.6ms NMS per image at shape (1, 3, 640, 480)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(result.render()))
plt.show()

# %%
result.show()
# Out:
# <PIL.Image.Image image mode=RGB size=308x434>

# %%
'''cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame=cap.read()
    
    result=model(frame)
    
    cv2.imshow('yolo', np.squeeze(result.render()))
    
    if cv2.waitKey(10) & 0XFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()'''
# Out:
# "cap = cv2.VideoCapture(0)\nwhile cap.isOpened():\n    ret, frame=cap.read()\n    \n    result=model(frame)\n    \n    cv2.imshow('yolo', np.squeeze(result.render()))\n    \n    if cv2.waitKey(10) & 0XFF == ord('q'):\n        break\ncap.release()\ncv2.destroyAllWindows()"

# %%
import uuid
import os
import time

# %%
#pip install opencv-contrib-python

# %%
#pip install opencv-contrib-python-headless

# %%
#pip install opencv-python

# %%
IMAGES_PATH =os.path.join('data','images')
labels=('Helmet', 'Human head', 'Motorcycle', 'Vehicle registration plate')
number_images=5

# %%
#!git clone https://github.com/heartexlabs/labelImg

# %%
#!pip install pyqt5 lxml --upgrade
#!cd labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
# !cd yolov5 && python train.py --img 320 --batch 1 --epochs 300 --data D:/projects/projectws/Helmet-Detection-and-Number-Plate-Recognition-Using-YOLO-master/helmetandnuberplate/data.yaml --weights D:/projects/projectws/Helmet-Detection-and-Number-Plate-Recognition-Using-YOLO-master/yolov5s.pt

# %%
# %cd yolov5
# !python detect.py --weights D:/projects/projectws/mainproject-django/mainproject/mainproject/yolov5/runs/train/exp/weights/bestcar.pt --img 416 --conf 0.4 --source D:/projects/projectws/Vehicle-Detection-main/test_images/imtest17.png
#import torch 
#model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp2/weights/last.pt')
# Out:
# [WinError 2] The system cannot find the file specified: 'yolov5'
# d:\projects\projectws\mainproject-django\mainproject\mainproject\yolov5
# detect: weights=['D:/projects/projectws/mainproject-django/mainproject/mainproject/yolov5/runs/train/exp/weights/bestcar.pt'], source=D:/projects/projectws/Vehicle-Detection-main/test_images/imtest17.png, data=data\coco128.yaml, imgsz=[416, 416], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-284-g95ebf68f Python-3.11.1 torch-2.2.0+cpu CPU
#
# Fusing layers...
# Model summary: 308 layers, 21053802 parameters, 0 gradients
# ...

# %%
import pytesseract
import os
final_plate="D:/projects/projectws/Helmet-Detection-and-Number-Plate-Recognition-Using-YOLO-master/yolov5/runs/detect/exp6/crops/license_plate/"
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
count=0
lst=[]
for i in os.listdir(final_plate):
        config = ('-l eng --oem 1 --psm 3')
        text = pytesseract.image_to_string("D:/projects/projectws/Helmet-Detection-and-Number-Plate-Recognition-Using-YOLO-master/yolov5/runs/detect/exp6/crops/license_plate/"+i, config=config)
        lst.append(text+str(count))
        count+=1

# %%
lst
# Out:
# ['AP13\n0.1700 |\n0',
#  '1',
#  '2',
#  '3',
#  'bel\nCYNE\n4',
#  '5',
#  'P APIS\n8735\n6',
#  '7']

# %%
img = os.path.join('data', 'images', '4a11e2446df66145.jpg')

# %%
img = "D:/projects/projectws/shanmukl/number plate detection/bikes/16.png"

# %%
results = model(img)

# %%
results
# Out:
# YOLOv5 <class 'models.common.Detections'> instance
# image 1/1: 370x266 2 License Plates
# Speed: 17.0ms pre-process, 407.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 480)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
#!pip uninstall opencv-python-headless -y
#!pip install opencv-python --upgrade

# %%
#!pip uninstall opencv-python 

#!pip install opencv-python

# %%
'''cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()'''

# %%
#pip list

# %%
#!pip uninstall opencv-python-headless 4.5.4.60

# %%
#pip list
